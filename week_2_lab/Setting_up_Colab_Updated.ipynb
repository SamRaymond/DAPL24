# %% [markdown]
# Google Colab Setup
#
#
# Sreevalli S
#
# Adapted from https://colab.research.google.com/?utm_source=scs-index ,
# ​
#
# ​
# https://stackoverflow.com/questions/67553747/how-do-i-link-a-github-repository-to-a-google-colab-notebook

# %% [markdown]
# <div class="markdown-google-sans">
#   <h2>What is Colab?</h2>
# </div>
#
# "Colab, or "Colaboratory", allows you to write and execute Python in your browser, with
# - Zero configuration required
# - Access to GPUs free of charge
# - Easy sharing"
#
# https://colab.research.google.com/?utm_source=scs-index

# %%
#install libraries

import pandas as pd
import numpy as np

# %% [markdown]
# ## Mounting Google Drive locally
#
# "The example below shows how to mount your Google Drive on your runtime using an authorization code, and how to write and read files there. Once executed, you will be able to see the new file (`foo.txt`) at [https://drive.google.com/](https://drive.google.com/).
#
# This only supports reading, writing, and moving files; to programmatically modify sharing settings or other metadata, use one of the other options below.
#
# **Note:** When using the 'Mount Drive' button in the file browser, no authentication codes are necessary for notebooks that have only been edited by the current user."
#
# https://colab.research.google.com/?utm_source=scs-index

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with open('/content/drive/My Drive/foo.txt', 'w') as f:
  f.write('DAPL!')
# !cat /content/drive/My\ Drive/foo.txt
# Out:
# DAPL!

# %%
drive.flush_and_unmount()
print('All changes made in this colab session should now be visible in Drive.')
# Out:
# All changes made in this colab session should now be visible in Drive.

# %% [markdown]
# ## Uploading Files
#
# "The example below shows how to mount your Google Drive on your runtime using an authorization code, and how to write and read files there. Once executed, you will be able to see the new file (`foo.txt`) at [https://drive.google.com/](https://drive.google.com/).
#
# This only supports reading, writing, and moving files; to programmatically modify sharing settings or other metadata, use one of the other options below.
#
# **Note:** When using the 'Mount Drive' button in the file browser, no authentication codes are necessary for notebooks that have only been edited by the current user."
#
# https://colab.research.google.com/?utm_source=scs-index

# %%
#upload the file from your system
from google.colab import files
uploaded = files.upload()
#upload a dataset such as the iris dataset.
# Out:
#      <input type="file" id="files-9cd93c44-7507-41fd-8f91-ec5114bf875e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9cd93c44-7507-41fd-8f91-ec5114bf875e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
iris= pd.read_csv("iris.csv")
iris
#can visualize what the dataset contains
# Out:
#      sepal length in cm  sepal width in cm  petal length in cm  \
# 0                   5.1                3.5                 1.4
# 1                   4.9                3.0                 1.4
# 2                   4.7                3.2                 1.3
# 3                   4.6                3.1                 1.5
# 4                   5.0                3.6                 1.4
# ..                  ...                ...                 ...
# 145                 6.7                3.0                 5.2
# 146                 6.3                2.5                 5.0
# 147                 6.5                3.0                 5.2
# 148                 6.2                3.4                 5.4
# 149                 5.9                3.0                 5.1
#
#      petal width in cm           class
# 0                  0.2     Iris-setosa
# 1                  0.2     Iris-setosa
# 2                  0.2     Iris-setosa
# 3                  0.2     Iris-setosa
# ...

# %% [markdown]
# ## Downloading Files

# %%
from google.colab import files

with open('DAPL.txt', 'w') as f:
  f.write('DAPL 2024')

files.download('DAPL.txt')

# %% [markdown]
# To save a copy, you can go to file, save a copy in github. You will need to login.

# %% [markdown]
# To use a github repo in colab: https://colab.research.google.com/
#
# Enter the details of the github repo and use.
